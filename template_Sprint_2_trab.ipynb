# %%
#!pip install psycopg2-binary
#!pip install seaborn
#!pip install pandas

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import psycopg2

# %%
conn = psycopg2.connect(host="server_name",
                        database="database_name", 
                        user="user_name", 
                        password="password")


cur = conn.cursor()

# %% [markdown]
# # Modelo Lógico do Trabalho

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #9.1 - Select simples das tabelas do database

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# ### inclur codigos acima para obter todas as tabelas do seu database

# %% [markdown]
# #9.2 - CONSULTAS DAS TABELAS COM FILTROS WHERE (Mínimo 4)

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# #9.3 - CONSULTAS QUE USAM OPERADORES LÓGICOS, ARITMÉTICOS E TABELAS OU CAMPOS RENOMEADOS (Mínimo 11)

# %% [markdown]
# * 9.3 (A) Criar 5 consultas que envolvam os operadores lógicos AND, OR e Not

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# * 9.3 (B) Criar no mínimo 3 consultas com operadores aritméticos

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# * 9.3 (C) Criar no mínimo 3 consultas com operação de renomear nomes de campos ou tabelas

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# # 9.4 - CONSULTAS QUE USAM OPERADORES LIKE E DATAS (Mínimo 12)

# %% [markdown]
# * 9.4 (A) Criar outras 5 consultas que envolvam like ou ilike

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# * 9.4 (B) Criar uma consulta para cada tipo de função data apresentada.

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# #9.5 - INSTRUÇÕES APLICANDO ATUALIZAÇÃO E EXCLUSÃO DE DADOS (Mínimo 6)

# %% [markdown]
# * 9.5 (A) Criar minimo 3 de exclusão

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %% [markdown]
# * 9.5 (B) Criar minimo 3 de atualização

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %% [markdown]
# #9.6 - CONSULTAS COM INNER JOIN E ORDER BY (Mínimo 6)

# %% [markdown]
# * 9.3 (A) Uma junção que envolva todas as tabelas possuindo no mínimo 2 registros no resultado

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# * 9.3 (B) Outras junções que o grupo considere como sendo as de principal importância para o trabalho

# %%
 res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# # 9.7 - CONSULTAS COM GROUP BY E FUNÇÕES DE AGRUPAMENTO (Mínimo 6)

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# # 9.8 - CONSULTAS COM LEFT, RIGHT E FULL JOIN (Mínimo 4)

# %% [markdown]
# * 9.8 (A) Criar minimo 1 de cada tipo

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %% [markdown]
# #9.9 - CONSULTAS COM SELF JOIN E VIEW (Mínimo 6)

# %%
res = pd.read_sql_query("""
<incluir instruções sql>
 """, conn)
res

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %% [markdown]
# #9.10 - SUBCONSULTAS (Mínimo 4)

# %% [markdown]
# * 9.10 (a) Criar minimo 1 envolvendo GROUP BY

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %% [markdown]
# * 9.10 (B) Criar minimo 1 envolvendo algum tipo de junção

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %% [markdown]
# * 9.10 (C) Criar minimo outras consultas pertinentes

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %%
cur.execute(""" 
<incluir instruções sql>
""")
conn.commit()

# %% [markdown]
# # Fechar conexão

# %%
conn.close()
